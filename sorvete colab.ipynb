# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("sakshisatre/ice-cream-sales-dataset")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'ice-cream-sales-dataset' dataset.
# Path to dataset files: /kaggle/input/ice-cream-sales-dataset

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a regression plot with a trend line
sns.regplot(x='Temperature', y='Revenue', data=df)

# Add labels and title
plt.xlabel('Temperature (°C)')
plt.ylabel('Revenue ($)')
plt.title('Ice Cream Revenue vs. Temperature')

# Show the plot
plt.show()

# %%
import pandas as pd
import os

# Construct the full path to the CSV file
csv_file_path = os.path.join(path, file_list[0])

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(csv_file_path)

# Display the first 5 rows of the DataFrame
print(df.head())
# Out:
#    Temperature  Revenue
# 0         24.6      535
# 1         26.1      626
# 2         27.8      661
# 3         20.6      488
# 4         11.6      317

# %%
import os

# List the files in the dataset directory
file_list = os.listdir(path)
print("Files in the dataset directory:", file_list)
# Out:
# Files in the dataset directory: ['Ice Cream.csv']
